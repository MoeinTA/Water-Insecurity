# %% [markdown]
# <a href="https://colab.research.google.com/github/MoeinTA/Water-Insecurity/blob/main/Water_Insecurity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-611925d6-29a1-44b8-bb32-38e3d081ffa4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-611925d6-29a1-44b8-bb32-38e3d081ffa4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('/content/water_insecurity_2023.csv', encoding = "latin-1")
water_insec23 = pd.read_csv('water_insecurity_2023.csv')

df.head()
# Out:
#    geoid                            name  year  \
# 0   1003         Baldwin County, Alabama  2023
# 1   1069         Houston County, Alabama  2023
# 2   6037  Los Angeles County, California  2023
# 3   6087   Santa Cruz County, California  2023
# 4   6097       Sonoma County, California  2023
#
#                                             geometry  total_pop  plumbing  \
# 0  list(list(c(765297.99052762, 765703.765676717,...     253507     271.0
# 1  list(list(c(975267.980555021, 975512.944547447...     108462      30.0
# 2  list(list(c(-2066923.36656991, -2066434.254456...    9663345    5248.0
# 3  list(list(c(-2284911.84626332, -2282456.220196...     261547     187.0
# 4  list(list(c(-2336932.55009848, -2336646.078244...     481812     308.0
#
#    percent_lacking_plumbing
# 0                  0.106900
# 1                  0.027659
# 2                  0.054308
# 3                  0.071498
# 4                  0.063925

# %%
water_insec23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 854 entries, 0 to 853
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   geoid                     854 non-null    int64
#  1   name                      854 non-null    object
#  2   year                      854 non-null    int64
#  3   geometry                  854 non-null    object
#  4   total_pop                 854 non-null    int64
#  5   plumbing                  853 non-null    float64
#  6   percent_lacking_plumbing  853 non-null    float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 46.8+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt

water_insec23 = pd.read_csv("water_insecurity_2023.csv")

print(water_insec23.head())

plt.bar(water_insec23['year'], water_insec23['plumbing'])
plt.xlabel('year')
plt.ylabel('plumbing')
plt.title('Insect Count by Year')
plt.show()
# Out:
#    geoid                            name  year  \
# 0   1003         Baldwin County, Alabama  2023
# 1   1069         Houston County, Alabama  2023
# 2   6037  Los Angeles County, California  2023
# 3   6087   Santa Cruz County, California  2023
# 4   6097       Sonoma County, California  2023
#
#                                             geometry  total_pop  plumbing  \
# 0  list(list(c(765297.99052762, 765703.765676717,...     253507     271.0
# 1  list(list(c(975267.980555021, 975512.944547447...     108462      30.0
# 2  list(list(c(-2066923.36656991, -2066434.254456...    9663345    5248.0
# 3  list(list(c(-2284911.84626332, -2282456.220196...     261547     187.0
# 4  list(list(c(-2336932.55009848, -2336646.078244...     481812     308.0
#
#    percent_lacking_plumbing
# 0                  0.106900
# 1                  0.027659
# 2                  0.054308
# 3                  0.071498
# 4                  0.063925

# %%
water_insec23.describe()
# Out:
#               geoid    year     total_pop     plumbing  \
# count    854.000000   854.0  8.540000e+02   853.000000
# mean   30586.902810  2023.0  3.374373e+05   253.726846
# std    16169.750921     0.0  5.777309e+05   438.988262
# min     1003.000000  2023.0  6.366100e+04     0.000000
# 25%    17125.000000  2023.0  9.674200e+04    41.000000
# 50%    34004.000000  2023.0  1.630865e+05   129.000000
# 75%    42105.500000  2023.0  3.483168e+05   299.000000
# max    72139.000000  2023.0  9.663345e+06  5248.000000
#
#        percent_lacking_plumbing
# count                853.000000
# mean                   0.101927
# std                    0.206700
# min                    0.000000
# 25%                    0.022079
# 50%                    0.060439
# 75%                    0.117170
# max                    3.913217
